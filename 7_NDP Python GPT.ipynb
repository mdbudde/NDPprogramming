# %% [markdown]
# ## ChatGPT example
#
# I pasted several columns into chatgpt4, with advanced data analysis (paid option)
#
# "create a figure plotting male versus female distance"
#
# Code copied from output

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the data
data = {
    "Sex": ["Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female",
            "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female",
            "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female",
            "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male",
            "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male",
            "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male"],
    "Distance": [49.813, 29.624, 58.209, 24.633, 24.503, 13.512, 16.761, 26.543, 36.589, 35.432,
                 43.552, 42.921, 38.593, 33.971, 29.014, 40.001, 29.046, 24.183, 127.017, 58.848,
                 49.713, 51.792, 38.13, 28.697, 24.634, 32.776, 35.114, 43.285, 38.734, 48.849,
                 36.337, 26.37, 47.927, 42.158, 33.675, 34.71, 63.826, 44.627, 35.483, 24.065,
                 23.641, 41.183, 58.582, 48.294, 50.571, 48.311, 34.419, 56.693, 42.616, 20.127,
                 27.146, 36.013, 48.401, 62.296, 22.541, 59.955, 19.136, 43.203, 25.576, 24.414]
}

# Create a dataframe
df = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(10, 6))
female_distances = df[df["Sex"] == "Female"]["Distance"]
male_distances = df[df["Sex"] == "Male"]["Distance"]

plt.boxplot([female_distances, male_distances], labels=["Female", "Male"])
plt.title("Distribution of Distances for Male vs Female")
plt.ylabel("Distance")
plt.grid(axis="y")

plt.show()

# %% [markdown]
# "plot again but also separating by treatment"

# %%
# Correcting the data definition and creating the dataframe again
data = {
    "Sex": ["Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female",
            "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female",
            "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female", "Female",
            "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male",
            "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male",
            "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male", "Male"],
    "Animal": ["87", "BQ472 2", "BQ472 5", "BF482 3", "CGN", "CGN", "140", "156", "111", "BY435 1",
               "88", "BQ472 3", "BF482 1", "BF482 4", "CGN", "138", "154", "178", "BY435 2", "BY435 3",
               "BQ472 1", "BQ472 4", "BF482 5", "BF482 2", "CGN", "139", "155", "179", "112", "113",
               "AV436", "AV436", "AS423", "WT-1", "WT-1", "AO418", "BF434 3", "BO440", "AV436 3", "75",
               "AV436", "AS423", "AS423", "WT-1", "AO418", "BF434 1", "BF434 4", "AV436 1", "AV436 4", "76",
               "AV436", "AS423", "WT-1", "AO418", "WT-1", "BF434 2", "BO440", "AV436 2", "AV436 5", "77"],
    "Treatment": ["WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A",
                  "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B",
                  "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C",
                  "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A", "WT-A",
                  "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B", "WT-B",
                  "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C", "WT-C"],
    "Distance": [49.813, 29.624, 58.209, 24.633, 24.503, 13.512, 16.761, 26.543, 36.589, 35.432,
                 43.552, 42.921, 38.593, 33.971, 29.014, 40.001, 29.046, 24.183, 127.017, 58.848,
                 49.713, 51.792, 38.13, 28.697, 24.634, 32.776, 35.114, 43.285, 38.734, 48.849,
                 36.337, 26.37, 47.927, 42.158, 33.675, 34.71, 63.826, 44.627, 35.483, 24.065,
                 23.641, 41.183, 58.582, 48.294, 50.571, 48.311, 34.419, 56.693, 42.616, 20.127,
                 27.146, 36.013, 48.401, 62.296, 22.541, 59.955, 19.136, 43.203, 25.576, 24.414]
}

# Create a dataframe
df = pd.DataFrame(data)

# Group the data by Sex and Treatment
groups = df.groupby(["Sex", "Treatment"])

# Extracting the data for plotting
plot_data = []
labels = []

for (sex, treatment), group_data in groups:
    plot_data.append(group_data["Distance"])
    labels.append(f"{sex} - {treatment}")

# Plot the data
plt.figure(figsize=(15, 8))
plt.boxplot(plot_data, labels=labels)
plt.title("Distribution of Distances by Sex and Treatment")
plt.ylabel("Distance")
plt.xticks(rotation=45)
plt.grid(axis="y")

plt.tight_layout()
plt.show()

# %% [markdown]
# "use seaborn instead"

# %%
import seaborn as sns

# Set the plot size and style
plt.figure(figsize=(15, 8))
sns.set_style("whitegrid")

# Create the boxplot using seaborn
sns.boxplot(x="Treatment", y="Distance", hue="Sex", data=df, palette="muted")

plt.title("Distribution of Distances by Sex and Treatment")
plt.ylabel("Distance")
plt.xlabel("Treatment")

plt.tight_layout()
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# "make it publication quality, increase font sizes, remove gridlines, change to black and white"

# %%
# Adjusting the plot colors to black and white

# Set the color palette to black and white shades
bw_palette = sns.color_palette("gray_r", 3)  # Three shades of gray for the three treatments

# Create the boxplot with the black and white palette
plt.figure(figsize=(10, 7))
sns.boxplot(x="Sex", y="Distance", hue="Treatment", data=df, palette=bw_palette, width=0.6)

# Setting the title and labels
plt.title("Distribution of Distances by Treatment and Sex", fontsize=18, pad=20)
plt.ylabel("Distance", fontsize=16)
plt.xlabel("Sex", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Customizing the legend
leg = plt.legend(loc='upper right', fontsize=12, title="Treatment")
leg.get_title().set_fontsize('14')  # Set fontsize for the legend title

# Remove the spines and gridlines
sns.despine()
sns.set_style("white")

# Displaying the plot with a tight layout
plt.tight_layout()
plt.show()
